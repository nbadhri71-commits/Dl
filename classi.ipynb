# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD,Adam
from sklearn.metrics import classification_report,confusion_matrix

# %%
data=load_breast_cancer()
x,y=data.data,data.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
model=Sequential([
    Dense(32,activation='relu',input_shape=(x_train.shape[1],)),
    Dense(16,activation='relu'),
    Dense(1,activation='sigmoid')
])
model.summary()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,537 (6.00 KB)
#  Trainable params: 1,537 (6.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=SGD(learning_rate=0.01),loss='binary_crossentropy',metrics=['accuracy'])
history=model.fit(x_train,y_train,validation_split=0.2,epochs=50,batch_size=32,verbose=0)

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(12,5))
ax1.plot(history.history['accuracy'])
ax1.plot(history.history['val_accuracy'])
ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
plt.tight_layout()
plt.show()

# %%
loss,accuracy=model.evaluate(x_test,y_test,verbose=0)
print(f"test accuracy: {accuracy*100:.2f}")
print(f"test loss:{loss:.4f}")
y_pred_prob=model.predict(x_test)
y_pred=(y_pred_prob>0.5).astype(int).flatten()
print("classification_report")
print(classification_report(y_test,y_pred))
# Out:
# test accuracy: 98.25
# test loss:0.0934
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# classification_report
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        43
#            1       0.97      1.00      0.99        71
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# 1. Generate synthetic dataset with 4 classes
x, y = make_classification(
    n_samples=500,
    n_features=30,
    n_informative=28,   # make sure sum <= n_features
    n_redundant=2,
    n_classes=4,
    random_state=42
)

# 2. One-hot encode the labels
y_cat = to_categorical(y, num_classes=4)

# 3. Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y_cat, test_size=0.2, random_state=42)

# 4. Standardize the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# 5. Build the model
model = Sequential([
    Dense(32, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(4, activation='softmax')  # 4 classes -> softmax activation
])

# 6. Compile the model
model.compile(
    optimizer=Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 7. Train the model
history = model.fit(
    x_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(x_test, y_test),
    verbose=1
)

# 8. Print model summary
model.summary()

# 9. Plot accuracy and loss
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Accuracy plot
ax1.plot(history.history['accuracy'], label='Train Accuracy')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Accuracy Over Epochs')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend()

# Loss plot
ax2.plot(history.history['loss'], label='Train Loss')
ax2.plot(history.history['val_loss'], label='Validation Loss')
ax2.set_title('Loss Over Epochs')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()

# 10. Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"\nTest Accuracy: {accuracy * 100:.2f}%")
print(f"Test Loss: {loss:.4f}")

# 11. Make predictions
y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = np.argmax(y_test, axis=1)

# 12. Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Epoch 1/50
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.2600 - loss: 1.4998 - val_accuracy: 0.3200 - val_loss: 1.4303
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3525 - loss: 1.3877 - val_accuracy: 0.3000 - val_loss: 1.3946
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4025 - loss: 1.3178 - val_accuracy: 0.3200 - val_loss: 1.3676
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4575 - loss: 1.2590 - val_accuracy: 0.3200 - val_loss: 1.3484
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4900 - loss: 1.2093 - val_accuracy: 0.3300 - val_loss: 1.3337
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5175 - loss: 1.1643 - val_accuracy: 0.3200 - val_loss: 1.3181
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5400 - loss: 1.1225 - val_accuracy: 0.3200 - val_loss: 1.3079
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5675 - loss: 1.0848 - val_accuracy: 0.3400 - val_loss: 1.2981
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6000 - loss: 1.0490 - val_accuracy: 0.3700 - val_loss: 1.2869
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6250 - loss: 1.0140 - val_accuracy: 0.3700 - val_loss: 1.2778
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6550 - loss: 0.9814 - val_accuracy: 0.3700 - val_loss: 1.2648
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6750 - loss: 0.9487 - val_accuracy: 0.3700 - val_loss: 1.2546
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6850 - loss: 0.9174 - val_accuracy: 0.3900 - val_loss: 1.2436
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6950 - loss: 0.8855 - val_accuracy: 0.4000 - val_loss: 1.2324
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7150 - loss: 0.8550 - val_accuracy: 0.4300 - val_loss: 1.2187
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7350 - loss: 0.8240 - val_accuracy: 0.4400 - val_loss: 1.2049
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7425 - loss: 0.7937 - val_accuracy: 0.4400 - val_loss: 1.1945
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7450 - loss: 0.7637 - val_accuracy: 0.4500 - val_loss: 1.1871
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7650 - loss: 0.7348 - val_accuracy: 0.4500 - val_loss: 1.1779
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7750 - loss: 0.7079 - val_accuracy: 0.4600 - val_loss: 1.1739
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7875 - loss: 0.6805 - val_accuracy: 0.4500 - val_loss: 1.1613
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8000 - loss: 0.6565 - val_accuracy: 0.4700 - val_loss: 1.1530
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8150 - loss: 0.6306 - val_accuracy: 0.4700 - val_loss: 1.1478
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8250 - loss: 0.6082 - val_accuracy: 0.4800 - val_loss: 1.1380
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8325 - loss: 0.5864 - val_accuracy: 0.4800 - val_loss: 1.1290
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8500 - loss: 0.5645 - val_accuracy: 0.5100 - val_loss: 1.1265
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8550 - loss: 0.5447 - val_accuracy: 0.5200 - val_loss: 1.1174
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8625 - loss: 0.5253 - val_accuracy: 0.5100 - val_loss: 1.1115
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8650 - loss: 0.5061 - val_accuracy: 0.5200 - val_loss: 1.1074
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8700 - loss: 0.4880 - val_accuracy: 0.5500 - val_loss: 1.1005
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8775 - loss: 0.4715 - val_accuracy: 0.5600 - val_loss: 1.0988
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8775 - loss: 0.4535 - val_accuracy: 0.5500 - val_loss: 1.0965
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8825 - loss: 0.4373 - val_accuracy: 0.5600 - val_loss: 1.0917
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8950 - loss: 0.4216 - val_accuracy: 0.5600 - val_loss: 1.0887
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9000 - loss: 0.4057 - val_accuracy: 0.5400 - val_loss: 1.0890
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9025 - loss: 0.3909 - val_accuracy: 0.5500 - val_loss: 1.0906
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9075 - loss: 0.3792 - val_accuracy: 0.5600 - val_loss: 1.0886
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9075 - loss: 0.3638 - val_accuracy: 0.5600 - val_loss: 1.0881
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9175 - loss: 0.3512 - val_accuracy: 0.5500 - val_loss: 1.0938
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9200 - loss: 0.3380 - val_accuracy: 0.5700 - val_loss: 1.0950
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9250 - loss: 0.3252 - val_accuracy: 0.5700 - val_loss: 1.0915
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9275 - loss: 0.3146 - val_accuracy: 0.6000 - val_loss: 1.0959
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9300 - loss: 0.3022 - val_accuracy: 0.5900 - val_loss: 1.1002
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9300 - loss: 0.2919 - val_accuracy: 0.6000 - val_loss: 1.0987
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9300 - loss: 0.2806 - val_accuracy: 0.6000 - val_loss: 1.1035
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9350 - loss: 0.2714 - val_accuracy: 0.5900 - val_loss: 1.1067
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9400 - loss: 0.2599 - val_accuracy: 0.6000 - val_loss: 1.1109
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9450 - loss: 0.2509 - val_accuracy: 0.6000 - val_loss: 1.1122
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9450 - loss: 0.2414 - val_accuracy: 0.6100 - val_loss: 1.1112
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9450 - loss: 0.2331 - val_accuracy: 0.6100 - val_loss: 1.1183
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 32)                  │             992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 4)                   │              68 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,766 (18.62 KB)
#  Trainable params: 1,588 (6.20 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,178 (12.42 KB)
# Test Accuracy: 61.00%
# Test Loss: 1.1183
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62        24
#            1       0.61      0.71      0.65        24
#            2       0.62      0.48      0.54        27
#            3       0.59      0.64      0.62        25
#
#     accuracy                           0.61       100
#    macro avg       0.61      0.61      0.61       100
# weighted avg       0.61      0.61      0.61       100

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification

# Generate synthetic dataset (for demonstration purposes)
x, y = make_classification(n_samples=500, n_features=30, n_informative=28,n_redundant=2, n_classes=2, random_state=42)

# Split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Scale the data
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# Define the model
model = Sequential([
    Dense(32, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_data=(x_test, y_test), verbose=1)

# Model summary
model.summary()

# Create the plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot accuracy
ax1.plot(history.history['accuracy'], label='Train Accuracy')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Accuracy Over Epochs')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend()

# Plot loss
ax2.plot(history.history['loss'], label='Train Loss')
ax2.plot(history.history['val_loss'], label='Validation Loss')
ax2.set_title('Loss Over Epochs')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend()

# Display the plots
plt.tight_layout()
plt.show()

# Evaluate the model on the test set
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Test accuracy: {accuracy * 100:.2f}%")
print(f"Test loss: {loss:.4f}")

# Predict on the test set
y_pred_prob = model.predict(x_test)
y_pred = (y_pred_prob > 0.5).astype(int).flatten()

# Print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/50
# C:\Users\HP\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.6225 - loss: 0.6458 - val_accuracy: 0.7300 - val_loss: 0.6074
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7150 - loss: 0.5919 - val_accuracy: 0.7600 - val_loss: 0.5789
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7700 - loss: 0.5514 - val_accuracy: 0.7600 - val_loss: 0.5554
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8075 - loss: 0.5137 - val_accuracy: 0.7800 - val_loss: 0.5348
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8250 - loss: 0.4794 - val_accuracy: 0.8000 - val_loss: 0.5163
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8350 - loss: 0.4475 - val_accuracy: 0.8300 - val_loss: 0.5016
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8475 - loss: 0.4168 - val_accuracy: 0.8100 - val_loss: 0.4890
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8575 - loss: 0.3898 - val_accuracy: 0.8000 - val_loss: 0.4786
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8850 - loss: 0.3636 - val_accuracy: 0.8000 - val_loss: 0.4718
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8900 - loss: 0.3399 - val_accuracy: 0.7800 - val_loss: 0.4605
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9050 - loss: 0.3173 - val_accuracy: 0.7800 - val_loss: 0.4551
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9100 - loss: 0.2958 - val_accuracy: 0.8000 - val_loss: 0.4464
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9225 - loss: 0.2752 - val_accuracy: 0.8200 - val_loss: 0.4411
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9325 - loss: 0.2561 - val_accuracy: 0.8200 - val_loss: 0.4348
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9375 - loss: 0.2390 - val_accuracy: 0.8200 - val_loss: 0.4253
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9425 - loss: 0.2229 - val_accuracy: 0.8200 - val_loss: 0.4214
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9500 - loss: 0.2072 - val_accuracy: 0.8200 - val_loss: 0.4140
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9600 - loss: 0.1929 - val_accuracy: 0.8200 - val_loss: 0.4078
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9600 - loss: 0.1788 - val_accuracy: 0.8400 - val_loss: 0.3981
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9650 - loss: 0.1663 - val_accuracy: 0.8400 - val_loss: 0.3931
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9650 - loss: 0.1552 - val_accuracy: 0.8400 - val_loss: 0.3918
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9725 - loss: 0.1441 - val_accuracy: 0.8400 - val_loss: 0.3848
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9775 - loss: 0.1346 - val_accuracy: 0.8500 - val_loss: 0.3753
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9775 - loss: 0.1245 - val_accuracy: 0.8500 - val_loss: 0.3716
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9800 - loss: 0.1165 - val_accuracy: 0.8500 - val_loss: 0.3683
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9800 - loss: 0.1082 - val_accuracy: 0.8600 - val_loss: 0.3605
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9850 - loss: 0.1009 - val_accuracy: 0.8700 - val_loss: 0.3593
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9850 - loss: 0.0939 - val_accuracy: 0.8700 - val_loss: 0.3542
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9850 - loss: 0.0876 - val_accuracy: 0.8700 - val_loss: 0.3511
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9850 - loss: 0.0815 - val_accuracy: 0.8700 - val_loss: 0.3473
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9875 - loss: 0.0760 - val_accuracy: 0.8700 - val_loss: 0.3428
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9900 - loss: 0.0708 - val_accuracy: 0.8700 - val_loss: 0.3387
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9925 - loss: 0.0659 - val_accuracy: 0.8700 - val_loss: 0.3321
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9950 - loss: 0.0617 - val_accuracy: 0.8700 - val_loss: 0.3308
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9950 - loss: 0.0574 - val_accuracy: 0.8700 - val_loss: 0.3288
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9950 - loss: 0.0533 - val_accuracy: 0.8700 - val_loss: 0.3279
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9950 - loss: 0.0500 - val_accuracy: 0.8700 - val_loss: 0.3253
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9950 - loss: 0.0466 - val_accuracy: 0.8700 - val_loss: 0.3242
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9950 - loss: 0.0436 - val_accuracy: 0.8700 - val_loss: 0.3222
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9950 - loss: 0.0403 - val_accuracy: 0.8700 - val_loss: 0.3209
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9950 - loss: 0.0377 - val_accuracy: 0.8700 - val_loss: 0.3197
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9975 - loss: 0.0352 - val_accuracy: 0.8700 - val_loss: 0.3213
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9975 - loss: 0.0327 - val_accuracy: 0.8700 - val_loss: 0.3178
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9975 - loss: 0.0307 - val_accuracy: 0.8700 - val_loss: 0.3187
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9975 - loss: 0.0286 - val_accuracy: 0.8700 - val_loss: 0.3199
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9975 - loss: 0.0269 - val_accuracy: 0.8700 - val_loss: 0.3166
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9975 - loss: 0.0251 - val_accuracy: 0.8700 - val_loss: 0.3167
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9975 - loss: 0.0237 - val_accuracy: 0.8700 - val_loss: 0.3163
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9975 - loss: 0.0221 - val_accuracy: 0.8700 - val_loss: 0.3176
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9975 - loss: 0.0208 - val_accuracy: 0.8700 - val_loss: 0.3130
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 32)                  │             992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,613 (18.02 KB)
#  Trainable params: 1,537 (6.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,076 (12.02 KB)
# Test accuracy: 87.00%
# Test loss: 0.3130
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A83A49C4A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/stepWARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A83A49C4A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88        54
#            1       0.88      0.83      0.85        46
#
#     accuracy                           0.87       100
#    macro avg       0.87      0.87      0.87       100
# weighted avg       0.87      0.87      0.87       100
